# %%
import pandas as pd
import numpy as np

# 可視化用のライブラリ
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

import neologdn
import MeCab

import re

# %%
df = pd.read_csv('all_text_wakatigaki.csv',encoding='utf-8')
df.head()
# Out:
#    surface     yomi original        type katsuyoukei katsuyougata  \
# 0  neologd  ネオログディー  NEologd  名詞-固有名詞-一般         NaN          NaN
# 1        _        _        _       記号-一般         NaN          NaN
# 2   tagger      タガー   tagger  名詞-固有名詞-一般         NaN          NaN
# 3        .        .        .       記号-一般         NaN          NaN
# 4    parse      パース    Parse  名詞-固有名詞-一般         NaN          NaN
#
#                                                   内容
# 0  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...
# 1  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...
# 2  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...
# 3  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...
# 4  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...

# %% [markdown]
# ### 文章毎に含まれる単語数をカウント

# %%
# [内容]カラムをグループ化しカウント　
# reset_index関数を使い[内容]カラムをindex部分からデータ列部分に戻す
per_sentence_word_cnt = df.groupby('内容')['original'].count().reset_index()

# カラム名を[original]から[word_cnt]に変更
per_sentence_word_cnt = per_sentence_word_cnt.rename(columns={'original':'word_cnt'})
# 確認
per_sentence_word_cnt
# Out:
#                                                   内容  word_cnt
# 0  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...        26
# 1  まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...        30
# 2     原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される        33
# 3  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...        41

# %%
# 文章全体の単語数をカウント(重複あり)
print('文章全体の単語数(重複あり)は{}語です。'.format(len(df)))
# Out:
# 文章全体の単語数(重複あり)は130語です。

# %% [markdown]
# ### 文章全体の単語数(重複なし)をカウント

# %%
unique_word_cnt = df['original'].nunique()
print('文章全体の単語数(重複なし)は{}語です。'.format(unique_word_cnt))
# Out:
# 文章全体の単語数(重複なし)は66語です。

# %% [markdown]
# ### 単語毎の出現回数をカウント

# %%
word_cnt_df = df['original'].value_counts().reset_index()

# カラム名を適切な名前に変更
word_cnt_df = word_cnt_df.rename(columns={'index':'original', 'original':'count'})

# 確認
word_cnt_df
# Out:
#    original  count
# 0        する      7
# 1         の      5
# 2         で      5
# 3         は      5
# 4         、      5
# 5         が      4
# 6        単語      4
# 7         に      4
# 8         型      4
# 9         」      4
# 10        「      3
# 11        を      3
# 12       れる      3
# 13        t      3
# 14        \      3
# 15        _      2
# 16      リスト      2
# 17        た      2
# 18       たい      2
# 19     text      2
# 20    split      2
# 21       使用      2
# 22       表示      2
# 23    分かち書き      2
# 24       品詞      2
# 25        n      2
# 26        て      2
# 27       原形      2
# 28    Parse      2
# 29      文字列      2
# ..      ...    ...
# 36      よって      1
# 37        。      1
# 38      ('\      1
# 39       次に      1
# 40      できる      1
# 41   tagger      1
# 42        (      1
# 43       関数      1
# 44       ため      1
# 45        群      1
# 46       いる      1
# 47       ので      1
# 48       省く      1
# 49       なる      1
# 50      区切り      1
# 51      区切る      1
# 52       邪魔      1
# 53        1      1
# 54  NEologd      1
# 55  wakatid      1
# 56       連続      1
# 57       ()      1
# 58       「\      1
# 59       1つ      1
# 60       ')      1
# 61        .      1
# 62       文字      1
# 63        各      1
# 64        だ      1
# 65        行      1
#
# [66 rows x 2 columns]

# %% [markdown]
# ## 単語毎の出現回数を縦棒グラフで可視化

# %%
word_cnt_df.plot.bar(x='original', figsize=(15,10))

# %% [markdown]
# ## 単語毎の出現回数を横棒グラフで可視化
# 棒グラフを横にする場合、最上位に表示されるのは出現回数が最小のものになってしまうのでまず出現回数(count)を昇順にする必要あり

# %%
word_cnt_df_sort = word_cnt_df.sort_values(by='count', ascending=True)
word_cnt_df_sort.plot.barh(x='original', figsize=(15,15))
